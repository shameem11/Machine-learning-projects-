# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train=pd.read_csv("/home/user/Desktop/data science/EDA/black_friday/train.csv")
df_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df_test=pd.read_csv('/home/user/Desktop/data science/EDA/black_friday/test.csv')
df_test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
df=pd.concat([df_train,df_test])
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %% [markdown]
# Drop unnecesary Columns

# %%
df.drop(['User_ID','Product_ID'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Gender   Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0      F  0-17          10             A                          2
# 1      F  0-17          10             A                          2
# 2      F  0-17          10             A                          2
# 3      F  0-17          10             A                          2
# 4      M   55+          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase
# 0    8370.0
# 1   15200.0
# 2    1422.0
# 3    1057.0
# 4    7969.0

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#from sklearn.preprocessing import LabelEncoder
#label=LabelEncoder()
#df['Age']=label.fit_transform(df['Age'])

# %%
df.head()
# Out:
#   Gender   Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0      F  0-17          10             A                          2
# 1      F  0-17          10             A                          2
# 2      F  0-17          10             A                          2
# 3      F  0-17          10             A                          2
# 4      M   55+          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase
# 0    8370.0
# 1   15200.0
# 2    1422.0
# 3    1057.0
# 4    7969.0

# %% [markdown]
# **Age Vs Purchase visualization**

# %%
sns.barplot(data=df,x='Age',y='Purchase',hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# **purchase  man is high then Woman**

# %%
data = df.groupby('Age')['Purchase'].mean()
data  = pd.DataFrame({'Age':data.index, 'Average_purchase':data.values})
plt.figure(figsize = (16,4))
plt.plot('Age','Average_purchase','ys-',data = data);
plt.grid();
plt.xlabel('Age group');
plt.ylabel('Average_Purchase amount in $');
plt.title('Age group vs average amount spent');

# %% [markdown]
# **age between 51-55 peoples spent more money on purchase.Approximate spent is 9700$**

# %% [markdown]
# Convert Gender to Numerical value

# %%
df['Gender']=df['Gender'].map({'F':0,'M':1})

# %% [markdown]
# Handle categorical Feature age  iam Here Target Encoding

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':7,'26-35':6,'36-45':5,'46-50':2,'51-55':3,'55+':4})

# %%
df_city=pd.get_dummies(df['City_Category'],dtype=int,drop_first=True)

# %%
df=pd.concat([df,df_city],axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0       0    1          10             A                          2
# 1       0    1          10             A                          2
# 2       0    1          10             A                          2
# 3       0    1          10             A                          2
# 4       1    4          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase  B  C
# 0    8370.0  0  0
# 1   15200.0  0  0
# 2    1422.0  0  0
# ...

# %%
df1=df.drop('City_Category',axis=1)

# %%
df1.dtypes
# Out:
# Gender                          int64
# Age                             int64
# Occupation                      int64
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# B                               int64
# C                               int64
# dtype: object

# %% [markdown]
# Find Missing values

# %%
df1.isna().sum()
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %% [markdown]
# ##Replace Missing value

# %%
df1['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df1['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df1['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: count, dtype: int64

# %% [markdown]
# Replace missing value by Mode

# %%
df1['Product_Category_2']=df1['Product_Category_2'].fillna(df1['Product_Category_2']).mode()[0]

# %%
df1['Product_Category_2'].isna().sum()
# Out:
# 0

# %%
df1['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df1['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
df1['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3']).mode()[0]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      783667 non-null  int64
#  1   Age                         783667 non-null  int64
#  2   Occupation                  783667 non-null  int64
#  3   Stay_In_Current_City_Years  783667 non-null  object
#  4   Marital_Status              783667 non-null  int64
#  5   Product_Category_1          783667 non-null  int64
#  6   Product_Category_2          783667 non-null  float64
#  7   Product_Category_3          783667 non-null  float64
#  8   Purchase                    550068 non-null  float64
#  9   B                           783667 non-null  int64
#  10  C                           783667 non-null  int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 71.7+ MB

# %% [markdown]
# **convert Object To intger**

# %%
df1['Stay_In_Current_City_Years'].head()
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4    4+
# Name: Stay_In_Current_City_Years, dtype: object

# %%
df1['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df1['Stay_In_Current_City_Years']=df1['Stay_In_Current_City_Years'].str.replace('+'," ")

# %%
df1['Stay_In_Current_City_Years'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 783667 entries, 0 to 233598
# Series name: Stay_In_Current_City_Years
# Non-Null Count   Dtype
# --------------   -----
# 783667 non-null  object
# dtypes: object(1)
# memory usage: 12.0+ MB

# %%
df1['Stay_In_Current_City_Years']=df1['Stay_In_Current_City_Years'].astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      783667 non-null  int64
#  1   Age                         783667 non-null  int64
#  2   Occupation                  783667 non-null  int64
#  3   Stay_In_Current_City_Years  783667 non-null  int64
#  4   Marital_Status              783667 non-null  int64
#  5   Product_Category_1          783667 non-null  int64
#  6   Product_Category_2          783667 non-null  float64
#  7   Product_Category_3          783667 non-null  float64
#  8   Purchase                    550068 non-null  float64
#  9   B                           783667 non-null  int64
#  10  C                           783667 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 71.7 MB

# %% [markdown]
# **train and test data classification**

# %%
df_ytest=df1[df1['Purchase'].isna()]
df_ytest
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0            1    2           7                           2               1
# 1            1    6          17                           0               0
# 2            0    5           1                           4               1
# 3            0    5           1                           4               1
# 4            0    6           1                           1               0
# ...        ...  ...         ...                         ...             ...
# 233594       0    6          15                           4               1
# 233595       0    6          15                           4               1
# 233596       0    6          15                           4               1
# 233597       0    2           1                           4               0
# 233598       0    2           0                           4               1
#
# ...

# %%
df_xtest=df1[~df1['Purchase'].isnull()]
df_xtest
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0            0    1          10                           2               0
# 1            0    1          10                           2               0
# 2            0    1          10                           2               0
# 3            0    1          10                           2               0
# 4            1    4          16                           4               0
# ...        ...  ...         ...                         ...             ...
# 550063       1    3          13                           1               1
# 550064       0    6           1                           3               0
# 550065       0    6          15                           4               1
# 550066       0    4           1                           2               0
# 550067       0    2           0                           4               1
#
# ...
