# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/height and weight.csv')
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#     Height
# 0     1.47
# 1     1.50
# 2     1.52
# 3     1.55
# 4     1.57
# 5     1.60
# 6     1.63
# 7     1.65
# 8     1.68
# 9     1.70
# 10    1.73
# 11    1.75
# 12    1.78
# 13    1.80
# 14    1.83

# %%
y=df['Weight']
y
# Out:
# 0     52.21
# 1     53.12
# 2     54.48
# 3     55.84
# 4     57.20
# 5     58.57
# 6     59.93
# 7     61.29
# 8     63.11
# 9     64.47
# 10    66.28
# 11    68.10
# 12    69.92
# 13    72.19
# 14    74.46
# Name: Weight, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#     Height
# 8     1.68
# 2     1.52
# 1     1.50
# 14    1.83
# 4     1.57
# 7     1.65
# 10    1.73
# 12    1.78
# 3     1.55
# 6     1.63

# %%
plt.scatter(x_train,y_train)
plt.xlabel('height')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([65.03579687, 68.13650836, 50.77252401, 71.23721985, 58.83437389])

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_pred)

# %%
print('slope is',model.coef_)
# Out:
# slope is [62.01422981]

# %%
print('intercept',model.intercept_)
# Out:
# intercept -40.388393810032014

# %% [markdown]
# create data fram actual and predict valuse

# %%
valu=pd.DataFrame({'actual_value':y_test,"predict_value":y_pred})
valu
# Out:
#     actual_value  predict_value
# 9          64.47      65.035797
# 11         68.10      68.136508
# 0          52.21      50.772524
# 13         72.19      71.237220
# 5          58.57      58.834374

# %%
from sklearn.metrics import mean_absolute_error
print('mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# mean absolute error 0.6513870508715769

# %%
#mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error
print('mean absolute percentage',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean absolute percentage 0.010911368997744855

# %%
#mean square error
print('mean absolute square error',mean_squared_error(y_test,y_pred))
# Out:
# mean absolute square error 0.6730959475011951

# %%
#root mean squate
root=mean_squared_error(y_test,y_pred)
ans=np.sqrt((root))
ans
# Out:
# 0.8204242484844015

# %%
#r2 score cofficence of determination

from sklearn.metrics import r2_score
print('r2 score is ',r2_score(y_test,y_pred))
# Out:
# r2 score is  0.986463232472019
