# %%
outlook=['sunny','sunny','overcast','rainy','rainy','rainy',
         'overcast','sunny','sunny','rainy','sunny',
         'overcast','overcast','rainy']

temperature=['hot','hot','hot','mild','cool','cool','cool','mild',
             'cool','mild','mild','mild','hot','mild']

humidity=['high','high','high','high','normal','normal','normal','high',
          'normal','normal','normal','high','normal','high']

wind=['weak','strong','weak','weak','weak','strong','strong',
      'weak','waek','weak','strong','strong','weak','strong']

play=['no','no','yes','yes','yes','no','yes','no','yes','yes',
      'yes','yes','yes','no']

# %% [markdown]
# #convert string in to numerical
# #encoding techniqe
#
#
# #lable encoding
#
# #one hot encoding
#
# #get_dumies

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
#convert string into numerical data outlook

outlook_encodede=le.fit_transform(outlook)
print(outlook_encodede)
temp_encoded=le.fit_transform(temperature)
humidity_encod=le.fit_transform(humidity)
wind_encoded=le.fit_transform(wind)
plat_encoded=le.fit_transform(play)
# Out:
# [2 2 0 1 1 1 0 2 2 1 2 0 0 1]

# %%
temp_encoded
# Out:
# array([1, 1, 1, 2, 0, 0, 0, 2, 0, 2, 2, 2, 1, 2])

# %% [markdown]
# #combain all list

# %%
feature=list(zip(outlook_encodede,temp_encoded,humidity_encod,wind_encoded))#here no normalization want
feature
# Out:
# [(2, 1, 0, 2),
#  (2, 1, 0, 0),
#  (0, 1, 0, 2),
#  (1, 2, 0, 2),
#  (1, 0, 1, 2),
#  (1, 0, 1, 0),
#  (0, 0, 1, 0),
#  (2, 2, 0, 2),
#  (2, 0, 1, 1),
#  (1, 2, 1, 2),
#  (2, 2, 1, 0),
#  (0, 2, 0, 0),
#  (0, 1, 1, 2),
#  (1, 2, 0, 0)]

# %% [markdown]
# #model creation
#
# #3 type of classifer
#
# #multinomial =
#
# #gaussian =
#
# #bernolli =

# %%
#model ctration
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()
model.fit(feature,play)
print(model.predict([[2,0,0,0]]))
# Out:
# ['no']
