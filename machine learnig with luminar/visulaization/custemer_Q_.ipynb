# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/customer5.txt',sep=',',header=None)
df
# Out:
#           0         1        2   3                              4       5  \
# 0   4000001  Kristina    Chung  55                          Pilot   india
# 1   4000002     Paige     Chen  74                        Teacher      uk
# 2   4000003    Sherri   Melton  34                    Firefighter      us
# 3   4000004  Gretchen     Hill  66     Computer hardware engineer   china
# 4   4000005     Karen  Puckett  74                         Lawyer  africa
# ..      ...       ...      ...  ..                            ...     ...
# 68  4000069   Melanie   Hewitt  47              Real estate agent      us
# 69  4000070  Marianne   Branch  53                          Judge      us
# 70  4000071   Natalie   Walton  24  Recreation and fitness worker      us
# 71  4000072  Caroline  O'Brien  44    Computer support specialist      us
# 72  4000073    Arlene     Case  62                       Musician      us
#
#           6
# 0     45000
# 1     45987
# 2     78956
# 3     98570
# ...

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %%
df.columns=['id','F_name','L_name','age','prof','country','salary']
df
# Out:
#          id    F_name   L_name  age                           prof country  \
# 0   4000001  Kristina    Chung   55                          Pilot   india
# 1   4000002     Paige     Chen   74                        Teacher      uk
# 2   4000003    Sherri   Melton   34                    Firefighter      us
# 3   4000004  Gretchen     Hill   66     Computer hardware engineer   china
# 4   4000005     Karen  Puckett   74                         Lawyer  africa
# ..      ...       ...      ...  ...                            ...     ...
# 68  4000069   Melanie   Hewitt   47              Real estate agent      us
# 69  4000070  Marianne   Branch   53                          Judge      us
# 70  4000071   Natalie   Walton   24  Recreation and fitness worker      us
# 71  4000072  Caroline  O'Brien   44    Computer support specialist      us
# 72  4000073    Arlene     Case   62                       Musician      us
#
#      salary
# 0     45000
# 1     45987
# 2     78956
# 3     98570
# ...

# %%
df.isna().sum()
# Out:
# id         0
# F_name     0
# L_name     0
# age        0
# prof       0
# country    0
# salary     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
prof=df.groupby('prof')['prof'].count()
prof
# Out:
# prof
# Accountant                         1
# Actor                              1
# Agricultural and food scientist    2
# Artist                             2
# Athlete                            2
# Carpenter                          3
# Childcare worker                   5
# Civil engineer                     3
# Computer hardware engineer         2
# Computer software engineer         1
# Computer support specialist        3
# Dancer                             1
# Doctor                             4
# Economist                          3
# Engineering technician             3
# Environmental scientist            1
# Financial analyst                  1
# Firefighter                        2
# Human resources assistant          1
# Judge                              1
# Lawyer                             3
# Musician                           5
# Pharmacist                         1
# Photographer                       1
# Physicist                          1
# ...

# %%
plt.hist(prof,color='blue')
plt.xlabel('count')
plt.ylabel('prof')
# Out:
# Text(0, 0.5, 'prof')
