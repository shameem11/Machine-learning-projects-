# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[8,9,11,10]
#plot
plt.plot(x,y)
plt.show()

# %%
import numpy as np
a=np.array([3,8,1,10,5,7])   #y defult x=machine
plt.plot(a)
plt.show()

# %%
C=np.array([5,6,7,8,9])
D=np.array([10,12,13,14,16])
plt.plot(C,D,marker='o')
plt.show()

# %%
AB=np.array([20,30,40,50,10])
BA=np.array([30,50,50,76,50])
plt.plot(AB,BA,marker='s')#s star
plt.show()

# %%
AC=np.array([20,30,40,50,10])
BC=np.array([30,50,50,76,50])
plt.plot(AC,BC,marker='+')#+ plus
plt.show()

# %%
AB=np.array([20,30,40,50,10])
BA=np.array([30,50,50,76,50])
plt.plot(AB,BA,marker='d')#s star
plt.show()

# %%
AB=np.array([20,30,40,50,10])
BA=np.array([30,50,50,76,50])
plt.plot(AB,BA,marker='p')#p pantagen
plt.show()

# %%
c=np.array([1,5,7,9])
plt.plot(c,'*:g')  #*marker :line  g=color

#line
#solid line=-
#dotted line=
#dashed line=--

#color
#r
#g
#b
#m
#y
#k
#w

# %%
c=np.array([1,5,7,9])
plt.plot(c,'d--b')

# %%
#marker property

z=np.array([40,50,60,30])
plt.plot(z,marker='o',ms=20,mec='r',mfc='g')#ms marker size

#ms= marker size
#mec =marker edge color
#mfc =marker face color

# %%
#line propertes

#line style
#line with
abc=np.array([30,50,70,30,50])
plt.plot(abc,linewidth=10)

# %%
x=[1,2,3,4]
x1=[10,20,40,65]
y=[2,6,4,8]
y1=[40,50,60,70]
plt.plot(x,x1)
plt.plot(y,y1)

# %%
#label
hight=[140,160,130,149]
weight=[64,75,81,68]
plt.plot(hight,weight,'8--g')
plt.xlabel('hight in cm')
plt.ylabel('weight in cm')
plt.title('Studence deatils')
# Out:
# Text(0.5, 1.0, 'Studence deatils')

# %%
hight=[140,160,130,149]
weight=[54,75,81,68]
plt.plot(hight,weight)
front1={'family':'serif',"color":'red','size':20}
front2={'family':'serif',"color":'yellow','size':30}
plt.xlabel('hight in cm',fontdict=front1)
plt.ylabel('weight in cm')
plt.title('Studence deatils',fontdict=front2)
# Out:
# Text(0.5, 1.0, 'Studence deatils')

# %%
hight=[140,160,130,149]
weight=[54,75,81,68]
plt.plot(hight,weight)
front1={'family':'serif',"color":'red','size':20}
front2={'family':'serif',"color":'yellow','size':30}
plt.xlabel('hight in cm',fontdict=front1)
plt.ylabel('weight in cm')
plt.title('Studence deatils',fontdict=front2)
plt.grid(color='green')
